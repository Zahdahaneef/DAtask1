# %%
print('Hello World') # display the welcome message using print
# Out:
# Hello World

# %%
Name = input('Whats your Name?') # taking input from user
Age = input('How old are you?')
Hobby = input("What is your favorite hobby? ")
print(f"\n Welcome {Name}!")
print(f"You are {Age} years old and love {Hobby}.") #Display a personalized message
# Out:
# Whats your Name?Zahda
# How old are you?28
# What is your favorite hobby? Watching dramas
#
#  Welcome Zahda!
# You are 28 years old and love Watching dramas.

# %%
# Taking input from user
print('Maths Calculation')
a = input("Enter first number: ")
b = input("Enter second number: ")

# Convert to numbers
a = float(a)
b = float(b)

# Perform calculations
print("\n--- Results ---")
print(f"Addition: {a + b}")
print(f"Subtraction: {a - b}")
print(f"Multiplication: {a * b}")
print(f"Division: {a / b}")
# Out:
# Maths Calculation
# Enter first number: 4
# Enter second number: 2
#
# --- Results ---
# Addition: 6.0
# Subtraction: 2.0
# Multiplication: 8.0
# Division: 2.0

# %%
food = ["Pizza","Biriyani","Rice","Loaded fries"] #listing favourite food
print('/n Favorite food')
print('Favourite food:',food[3])
# Out:
# /n Favorite food
# Favourite food: Loaded fries

# %%
print('/n ---Bio Data---') #display biodata
print('Name:',Name)
print('Age:',Age)
print('Hobby:',Hobby)
# Out:
# /n ---Bio Data---
# Name: Zahda
# Age: 28
# Hobby: Watching dramas
